# %%
# import flywheel package
import flywheel

# Create client
fw = flywheel.Client()

# %%
import os
import numpy as np
import pandas as pd

# %%
test_query = "subject.type = animal"
# "file", "acquisition", "session", "analysis", "collection"
test_return_type = "session"

# %%
def search_to_df(return_type,query):
    

    # Create search object
    search = fw.search({'return_type': return_type, 'structured_query': query},size=10000)
    # If no results returned, exit
    if len(search) == 0:
        print('No results returned for search query: {}'.format(query))
        return
    # Initialize data frame list
    df_list = []
    # Iterate over every search item
    for item in search:
        # Set data view object based on return type
        if return_type == 'file':
            return_id = item.parent.id
            df_column = 'acquisition.id'
            view_builder = flywheel.ViewBuilder(columns=['file.name','file.type','project.label'],
                                        container='acquisition', include_ids=True,
                                        include_labels=True, process_files=False,filename=item.file.name)
            # Build the view
            view = view_builder.build()
        elif return_type == 'acquisition':
            view = fw.View(columns=['acquisition.timestamp','acquisition.label'])
            return_id = item[return_type].id
            df_column = return_type + '.id'
        elif return_type == 'session':
            view = fw.View(columns=['session.timestamp','subject.label','project.label'])
            return_id = item[return_type].id
            df_column = return_type + '.id'
        else:
            print('Invalid return_type: {}'.format(return_type))
            os.sys.exit(1)
        project_id = item.project.id
        tmp_df = fw.read_view_dataframe(view, project_id)
    
        tmp_df = tmp_df[tmp_df[df_column]==return_id]
        if len(tmp_df) == 0:
            print("df empty for return id: {}".format(return_id))
        df_list.append(tmp_df)
    df = pd.concat(df_list,ignore_index=True)   
    return df

# %%
test_df = search_to_df('file',test_query)
# Out:
# df empty for return id: 5c9bb6a65cd73e002dca9c05
# df empty for return id: 576bf0d859b2b6346719f208
# df empty for return id: 576bf0d859b2b6346719f208
# df empty for return id: 576bf0d859b2b6346719f208
# df empty for return id: 5bef3234f1f9290011393f71
# df empty for return id: 5bef3234f1f9290011393f71
# df empty for return id: 5bef3336f1f9290016993c46
# df empty for return id: 5bef3336f1f9290016993c46
# df empty for return id: 5bd1d789884a86001b990c81
# df empty for return id: 5bd1d789884a860015990fbf
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c8467b8c1019001800d36e
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d714
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d710
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846948c1019001300d712
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d716
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d718
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d720
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71a
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71c
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846958c1019001300d71e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 58c846948c1019001300d70e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5bb633a3f9090600146cec4e
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5b895a6cb405ca0010c79472
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0
# df empty for return id: 5cd485553dac8900370f0ca0

# %%
test_df.shape
# Out:
# (134, 10)

# %%
fw.get('5c9bb6a65cd73e002dca9c05')
# Out:
# {'age': None,
#  'analyses': [],
#  'code': 'C10_602',
#  'cohort': None,
#  'created': datetime.datetime(2019, 3, 27, 17, 45, 10, 768000, tzinfo=tzutc()),
#  'ethnicity': None,
#  'files': [{'classification': {},
#             'created': datetime.datetime(2019, 3, 27, 17, 46, 59, 441000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-e8134738ff308c71f622892446ee324155a11e72e6e3c7f25cec474af3679c97964ba170114eaadfdbf53c5d94394b38',
#             'id': '8e75d778-9478-43f1-8dbe-8bde91ceb1b0',
#             'info': {},
#             'info_exists': None,
#             'mimetype': 'application/octet-stream',
#             'modality': None,
#             'modified': datetime.datetime(2019, 3, 27, 17, 46, 58, 767000, tzinfo=tzutc()),
#             'name': 'input.metadata.xlsx',
#             'origin': {'id': 'kalebfischer@flywheel.io',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 10038,
#             'tags': [],
#             'type': 'spreadsheet',
#             'zip_member_count': None}],
#  'firstname': None,
#  'id': '5c9bb6a65cd73e002dca9c05',
#  'info': {},
#  'info_exists': None,
#  'label': 'C10_602',
#  'lastname': None,
#  'modified': datetime.datetime(2019, 5, 14, 15, 10, 25, 500000, tzinfo=tzutc()),
#  'notes': [],
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'small_animal_studies',
#              'project': '5c93ce49742f310029782434',
#              'session': None,
#              'subject': None},
#  'permissions': [{'access': 'admin', 'id': 'kalebfischer@flywheel.io'},
#                  {'access': 'admin', 'id': 'sinaaslan@flywheel.io'}],
#  'project': '5c93ce49742f310029782434',
#  'public': None,
#  'race': None,
#  'sex': None,
#  'species': 'mouse',
#  'strain': None,
#  'tags': [],
#  'type': 'animal'}

# %%
search = fw.search({'return_type': 'file', 'structured_query': test_query},size = 500)

# %%
import argparse
ap = argparse.ArgumentParser()
ap.add_argument.__doc__
# Out:
# '\n        add_argument(dest, ..., name=value, ...)\n        add_argument(option_string, option_string, ..., name=value, ...)\n        '

# %%
len(search)
# Out:
# 390

# %%
fw.search.__doc__
# Out:
# 'Perform a search query\n\n\n        :param SearchQuery body: (required)\n        :param bool simple:\n        :param int size:\n        :param bool async_: Perform the request asynchronously\n        :return: list[SearchResponse]\n        '

# %%
view = fw.View(columns = 'file')

search = fw.search({'return_type': 'file', 'structured_query': test_query})
fw.read_view_dataframe(view, search[0].project.id)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-252-8f5813868c1e> in <module>
#       2
#       3 search = fw.search({'return_type': 'file', 'structured_query': test_query})
# ----> 4 fw.read_view_dataframe(view, search[0].project.id)
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/client.py in read_view_dataframe(self, view, container_id, opts, **kwargs)
#     225         :return: A pandas DataFrame
#     226         """
# --> 227         return self._fw.read_view_dataframe(view, container_id, opts=opts, **kwargs)
#     228
#     229
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/flywheel.py in read_view_dataframe(self, view, container_id, opts, **kwargs)
#    6875
#    6876         kwargs['format'] = 'json-flat'
# -> 6877         resp = self.read_view_data(view, container_id, decode=False, **kwargs)
#    6878         if resp:
#    6879             try:
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/flywheel.py in read_view_data(self, view, container_id, decode, **kwargs)
#    6851             resp = self.views_api.evaluate_view_with_http_info(view, container_id, **kwargs)
#    6852         else:
# -> 6853             resp = self.views_api.evaluate_view_adhoc_with_http_info(container_id, view, **kwargs)
#    6854         resp.raw.decode_content = True
#    6855         if decode:
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api/views_api.py in evaluate_view_adhoc_with_http_info(self, container_id, body, **kwargs)
#     453             _request_timeout=params.get('_request_timeout'),
#     454             _request_out=params.get('_request_out'),
# --> 455             collection_formats=collection_formats)
#     456
#     457     def get_view(self, view_id, **kwargs):  # noqa: E501
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _request_out)
#     348                                    response_type, auth_settings,
#     349                                    _return_http_data_only, collection_formats,
# --> 350                                    _preload_content, _request_timeout, _request_out)
#     351         else:
#     352             thread = self.pool.apply_async(self.__call_api, (resource_path,
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _request_out)
#     178             post_params=post_params, body=body,
#     179             _preload_content=_preload_content,
# --> 180             _request_timeout=_request_timeout)
#     181
#     182         self.last_response = response_data
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     391                                          _preload_content=_preload_content,
#     392                                          _request_timeout=_request_timeout,
# --> 393                                          body=body)
#     394         elif method == "PUT":
#     395             return self.rest_client.PUT(url,
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/rest.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     223                             _preload_content=_preload_content,
#     224                             _request_timeout=_request_timeout,
# --> 225                             body=body)
#     226
#     227     def PUT(self, url, headers=None, query_params=None, post_params=None,
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     126                     stream=stream,
#     127                     timeout=_request_timeout,
# --> 128                     headers=headers)
#     129             elif headers['Content-Type'] == 'application/x-www-form-urlencoded':  # noqa: E501
#     130                 r = self.session.request(method, url,
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     651
#     652         # Response manipulation hooks
# --> 653         r = dispatch_hook('response', hooks, r, **kwargs)
#     654
#     655         # Persist cookies
#
# ~/anaconda3/lib/python3.7/site-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29             hooks = [hooks]
#      30         for hook in hooks:
# ---> 31             _hook_data = hook(hook_data, **kwargs)
#      32             if _hook_data is not None:
#      33                 hook_data = _hook_data
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/rest.py in response_hook(self, resp, *args, **kwargs)
#      76     def response_hook(self, resp, *args, **kwargs):
#      77         if not 200 <= resp.status_code <= 299 and resp.status_code != 302:
# ---> 78             raise ApiException(http_resp=resp)
#      79
#      80     def request(self, method, url, query_params=None, headers=None,
#
# ApiException: (500) Reason: Internal Server Error

# %%
search = fw.search({'return_type': 'file', 'structured_query': test_query})
view_builder = flywheel.ViewBuilder(columns=['file.name','file.type','project.label'],
                                    container='acquisition', include_ids=True,
                                    include_labels=True, process_files=False,filename=search[0].file.name)


# Build the view
buildview = view_builder.build()

# %%
query2 = "subject.type != animal"
analysis_search = fw.search({'return_type': 'analysis', 'structured_query': query2},size = 10000)
file_search = fw.search({'return_type': 'file', 'structured_query': query2},size = 10000)
session_search = fw.search({'return_type': 'session', 'structured_query': query2},size = 10000)
acquisition_search = fw.search({'return_type': 'acquisition', 'structured_query': query2},size = 10000)

# %%
eval("analysis_search[0].{}".format("analysis.id"))
# Out:
# '5798e82ab2e765001f65daa3'

# %%
column_dict = {}
column_dict['acquisition'] = ['acquisition.id', 'acquisition.label', 'acquisition.created',
                              'session.label', 'session.id', 'project.label', 'project.id']
column_dict['session'] = ['session.label', 'session.id', 'session.created',
                          'subject.code', 'project.label', 'project.id']
column_dict['analysis'] = ['analysis.label','analysis.id','project.label','project.id','analysis.created']
column_dict['file'] = ['file.name', 'file.type', 'project.label', 'project.id','session.label','session.id']

def create_dataframe(return_type, query, column_list=None):
    df_list = []
    search = fw.search({'return_type': return_type, 'structured_query': query}, size = 10000)
    if not column_list:
        column_list = get_columns(search[0].to_dict())
    for search_item in search:
        tmp_dict = {}
        for column in column_list:
            try:
                tmp_dict[column] = [eval("search_item.{}".format(column))]
            except AttributeError:
                tmp_dict[column] = ''
        tmp_df = pd.DataFrame(data=tmp_dict)
        df_list.append(tmp_df)
    df = pd.concat(df_list,ignore_index=True)
    return df

# %%
query2 = 'subject.species = mouse'
acquisition_df = create_dataframe('acquisition', query2)
session_df = create_dataframe('session', query2)
file_df = create_dataframe('file', query2)
analysis_df = create_dataframe('analysis', query2)

# %%
session_df.to_json()
# Out:
# '{"return_type":{"0":"session","1":"session"},"project.id":{"0":"5c93ce49742f310029782434","1":"5c93ce49742f310029782434"},"project.label":{"0":"ice_mice","1":"ice_mice"},"group.id":{"0":"small_animal_studies","1":"small_animal_studies"},"group.label":{"0":"Small Animal Studies","1":"Small Animal Studies"},"session.id":{"0":"5c9bb6a65cd73e002dca9c06","1":"5cd5d5d5c969cf0029a2c1c6"},"session.label":{"0":"plethysmography","1":"test_inveon"},"session.timestamp":{"0":1553708640000,"1":1557517740000},"session.created":{"0":1553708710756,"1":1557517780997},"acquisition":{"0":null,"1":null},"subject.code":{"0":"C10_602","1":"test"},"file":{"0":null,"1":null},"collection":{"0":null,"1":null},"analysis":{"0":null,"1":null},"parent":{"0":null,"1":null}}'

# %%
def get_columns(d, keystring=''):
    key_list = []
    for k,v in d.items():        
        if isinstance(v, dict):
            newkeystring = keystring+k+'.'
            key_list += iterdict(v,newkeystring)
        elif isinstance(v,list):
            pass
        else: 
            #keystring = keystring+k
            if keystring == '':
                string = k
            else:
                string = keystring+k
            key_list.append(string)
    return key_list

# %%
def get_keys(d, keystring=''):
    key_list = []
    for k,v in d.items():        
        if isinstance(v, dict):
            newkeystring = keystring+k+'.'
            key_list += get_keys(v,newkeystring)
        elif isinstance(v,list):
            pass
        else: 
            #keystring = keystring+k
            if keystring == '':
                string = k
            else:
                string = keystring+k
            key_list.append(string)
    return key_list

# %%
def filter_search(search, column_list):
    filtered_search = []
    for result in search:
        result_dict = {}
        for column in column_list:
            try:
                result_dict[column] = eval("result.{}".format(column))
            except AttributeError:
                result_dict[column] = ""
            if type(result_dict[column])==datetime.datetime:
                result_dict[column] = str(result_dict[column])
        filtered_search.append(result_dict)
    return filtered_search

# %%
column_list2 = get_keys(session_search[0].to_dict())
column_list1 = ['session.id','session.label']
filtered_session_search = filter_search(session_search,column_list2)

# %%
def search_to_csv(search,filepath):
    df_list = []
    for result in search:
        tmp_dict = {}
        for key, value in result.items():
            tmp_dict[key] = [value]
        tmp_df = pd.DataFrame(data=tmp_dict)
        df_list.append(tmp_df)
    df = pd.concat(df_list, ignore_index=True)
    csv_path = path + '.csv'
    df.to_csv(csv_path,index=False)

# %%
search_to_csv(filtered_session_search,"test")

# %%
import datetime
for key,value in filtered_session_search[0].items():
    if type(value)== datetime.datetime:
        str(value)
# Out:
# 2015-01-07 17:30:03+00:00
# 2016-06-23 13:56:53.997000+00:00

# %%
session_search[0].to_dict()['return_type']
# Out:
# 'session'

# %%
df = fw.read_view_dataframe(buildview, search[0].project.id)
df[df['acquisition.id']==search[0].parent.id]
# Out:
#              acquisition.id acquisition.label              file.name  \
# 0  576d224aa02c8621973ed2fb     fMRI_Ret_bars  8613_8_1_fmri.dcm.zip
#
#   file.type                project.id  project.label  \
# 0     dicom  576be50c59b2b6346719ee4d  Anxiety Study
#
#                  session.id                 session.label  \
# 0  576bf0d859b2b6346719f208  ccirc_sub_6_ccirc_ses2_protB
#
#                  subject.id subject.label
# 0  5ab4226f25cd370001cee619   ccirc_sub_6

# %%
for key in view.keys():
    print(key)
    print(view[key])
    print(buildview[key])
# Out:
# parent
# None
# None
# label
# None
# None
# public
# False
# False
# columns
# [{'dst': None, 'expr': None, 'src': 'file', 'type': None}]
# [{'dst': 'PatientID', 'expr': None, 'src': 'subject.label', 'type': None}, {'dst': 'PixelSpacing',
#  'expr': None,
#  'src': 'file.info.header.dicom.PixelSpacing',
#  'type': None}, {'dst': 'StudyInstanceUID',
#  'expr': None,
#  'src': 'file.info.header.dicom.StudyInstanceUID',
#  'type': None}, {'dst': 'SeriesInstanceUID',
#  'expr': None,
#  'src': 'file.info.header.dicom.SeriesInstanceUID',
#  'type': None}, {'dst': 'SpacingBetweenSlices',
#  'expr': None,
#  'src': 'file.info.header.dicom.SpacingBetweenSlices',
#  'type': None}, {'dst': 'MagneticFieldStrength',
#  'expr': None,
#  'src': 'file.info.header.dicom.MagneticFieldStrength',
#  'type': None}, {'dst': 'EchoTime',
#  'expr': None,
#  'src': 'file.info.header.dicom.EchoTime',
#  'type': None}, {'dst': 'RepetitionTime',
#  'expr': None,
#  'src': 'file.info.header.dicom.RepetitionTime',
#  'type': None}, {'dst': 'deleted', 'expr': None, 'src': 'acquisition.deleted', 'type': None}]
# fileSpec
# None
# {'analysis_filter': None,
#  'columns': [],
#  'container': 'acquisition',
#  'filter': {'regex': None, 'value': '*.dicom.zip'},
#  'format': None,
#  'format_options': {},
#  'match': 'oldest',
#  'process_files': False,
#  'zip_member': None}
# includeIds
# True
# False
# includeLabels
# True
# False
# missingDataStrategy
# None
# None
# _id
# None
# None

# %%
for item in search:
    if item.subject:
        print(item.subject)
        print(fw.subjects.find_first('code={}'.format(item.subject.code)).type)
# Out:
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'ccirc_sub_6'}
# animal
# {'code': 'sub-51040hj'}
# animal
# {'code': 'sub1'}
# None
# {'code': 'fdsa'}
# animal
# {'code': 'sub-51040hj'}
# animal
# {'code': 'sub-51040hj'}
# animal
# {'code': 'sub-51040hj'}
# animal
# {'code': 'sub1'}
# None

# %%
search[0]
# Out:
# {'acquisition': None,
#  'analysis': None,
#  'collection': None,
#  'file': {'classification': {'Intent': ['Structural'],
#                              'Measurement': ['Diffusion']},
#           'created': datetime.datetime(2016, 6, 23, 11, 44, 34, 46000, tzinfo=tzutc()),
#           'name': '8892_14_1_dti.dcm.zip',
#           'size': 36090959,
#           'type': 'dicom'},
#  'group': {'id': 'neuroscience', 'label': 'Neuroscience Group'},
#  'parent': {'analyses': None,
#             'collections': None,
#             'created': None,
#             'files': None,
#             'id': '576d2069a02c8621973ed19b',
#             'info': None,
#             'info_exists': None,
#             'label': None,
#             'modified': None,
#             'notes': None,
#             'parents': None,
#             'permissions': None,
#             'public': None,
#             'session': None,
#             'tags': None,
#             'timestamp': None,
#             'timezone': None,
#             'uid': None},
#  'permissions': [{'access': 'admin', 'id': 'ryansanford@flywheel.io'},
#                  {'access': 'admin', 'id': 'canakgun@flywheel.io'},
#                  {'access': 'admin', 'id': 'nathanielkofalt@flywheel.io'},
#                  {'access': 'admin', 'id': 'michaelperry@flywheel.io'},
#                  {'access': 'admin', 'id': 'imadnijim@flywheel.io'},
#                  {'access': 'admin', 'id': 'elisapoquette@flywheel.io'},
#                  {'access': 'admin', 'id': 'gsfr@flywheel.io'},
#                  {'access': 'admin', 'id': 'mandavollmers@flywheel.io'},
#                  {'access': 'admin', 'id': 'chriserikstrup@flywheel.io'},
#                  {'access': 'admin', 'id': 'danpuccetti@flywheel.io'},
#                  {'access': 'admin', 'id': 'maxbailey@flywheel.io'},
#                  {'access': 'admin', 'id': 'ryanchamberlain@invenshure.com'},
#                  {'access': 'admin', 'id': 'renzofrigato@flywheel.io'},
#                  {'access': 'admin', 'id': 'wandell@stanford.edu'},
#                  {'access': 'admin', 'id': 'meganhenning@flywheel.io'},
#                  {'access': 'ro', 'id': 'lastrhino@gmail.com'},
#                  {'access': 'admin', 'id': 'chrisbaldock@flywheel.io'},
#                  {'access': 'admin', 'id': 'vipulgoel@flywheel.io'},
#                  {'access': 'rw', 'id': 'inijim@gmail.com'},
#                  {'access': 'admin', 'id': 'wsonbol@gmail.com'},
#                  {'access': 'rw', 'id': 'ashketchum@gmail.com'},
#                  {'access': 'admin', 'id': 'ashleyancona@flywheel.io'},
#                  {'access': 'admin', 'id': 'justinehlert@flywheel.io'},
#                  {'access': 'admin', 'id': 'harshakethineni@flywheel.io'},
#                  {'access': 'ro', 'id': 'tylermoncur@flywheel.io'},
#                  {'access': 'admin', 'id': 'jeffmeier@flywheel.io'},
#                  {'access': 'admin', 'id': 'sinaaslan@flywheel.io'},
#                  {'access': 'admin', 'id': 'kalebfischer@flywheel.io'}],
#  'project': {'id': '576be9a259b2b6346719f074', 'label': 'Cerebellum Circuitry'},
#  'return_type': 'file',
#  'session': {'created': datetime.datetime(2016, 6, 23, 13, 52, 38, 261000, tzinfo=tzutc()),
#              'id': '576be9a659b2b6346719f080',
#              'label': 'ccirc_sub_1_ccirc_ses1_protA',
#              'timestamp': None},
#  'subject': {'code': 'megan_test'}}

# %%
dir(fw.print_view_columns())
# Out:
# project (group): All column aliases belonging to project
# project.id (string): The project id
# project.label (string): The project label
# project.info (object): The freeform project metadata
# subject (group): All column aliases belonging to subject
# subject.id (string): The subject id
# subject.label (string): The subject label or code
# subject.firstname (string): The subject first name
# subject.lastname (string): The subject last name
# subject.sex (string): The subject sex (one of female|male|other|unknown)
# subject.race (string): The subject race (one of American Indian or Alaska Native|Asian|Native Hawaiian or Other Pacific Islander|Black or African American|White|More Than One Race|Unknown or Not Reported)
# subject.ethnicity (string): The subject ethnicity (one of Not Hispanic or Latino|Hispanic or Latino|Unknown or Not Reported)
# subject.cohort (string): The subject cohort (one of Control|Study|Training|Test|Validation)
# subject.type (string): The subject type (one of human|animal|phantom)
# subject.species (string): The subject species
# subject.strain (string): The subject strain
# subject.info (object): The freeform subject metadata
# session (group): All column aliases belonging to session
# session.id (string): The session id
# session.label (string): The session label
# session.operator (string): The session operator name
# session.timestamp (string): The session timestamp
# session.timezone (string): The session timezone
# session.info (object): The freeform session metadata
# session.age (int): The subject age at time of session, in seconds
# session.age_years (float): The subject age at time of session, in years
# session.age_months (float): The subject age at time of session, in months
# session.age_weeks (float): The subject age at time of session, in weeks
# session.age_days (float): The subject age at time of session, in days
# session.weight (float): The subject weight at time of session, in kg
# acquisition (group): All column aliases belonging to acquisition
# acquisition.id (string): The acquisition id
# acquisition.label (string): The acquisition label
# acquisition.timestamp (string): The acquisition timestamp
# acquisition.timezone (string): The acquisition timezone
# acquisition.info (object): The freeform acquisition metadata
# analysis (group): All column aliases belonging to analysis
# analysis.id (string): The analysis id
# analysis.label (string): The analysis label
# analysis.info (object): The freeform analysis metadata
# file (group): All column aliases belonging to file
# file.id (string): The file id
# file.name (string): The filename
# file.type (string): The type of file (e.g., dicom, image, document)
# file.mimetype (string): The file mime type (e.g. application/json, text/csv)
# file.modality (string): The file instrument type (e.g., MR, CT)
# file.classification (string): The file classification object
# file.size (int): The size of the file, in bytes
# file.row_number (int): The 0-indexed row number from file
# file.info (object): The freeform file metadata
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
search[0]
# Out:
# {'acquisition': None,
#  'analysis': None,
#  'collection': None,
#  'file': None,
#  'group': {'id': 'psychology', 'label': 'Psychology Group'},
#  'parent': None,
#  'permissions': [{'access': 'admin', 'id': 'ryansanford@flywheel.io'},
#                  {'access': 'admin', 'id': 'michaelperry@flywheel.io'},
#                  {'access': 'admin', 'id': 'imadnijim@flywheel.io'},
#                  {'access': 'admin', 'id': 'mandavollmers@flywheel.io'},
#                  {'access': 'admin', 'id': 'gsfr@flywheel.io'},
#                  {'access': 'admin', 'id': 'chriserikstrup@flywheel.io'},
#                  {'access': 'rw', 'id': 'danpuccetti@flywheel.io'},
#                  {'access': 'rw', 'id': 'maxbailey@flywheel.io'},
#                  {'access': 'admin', 'id': 'ryanchamberlain@invenshure.com'},
#                  {'access': 'admin', 'id': 'renzofrigato@flywheel.io'},
#                  {'access': 'admin', 'id': 'wandell@stanford.edu'},
#                  {'access': 'ro', 'id': 'lastrhino@gmail.com'},
#                  {'access': 'admin', 'id': 'thadbrown@flywheel.io'},
#                  {'access': 'ro', 'id': 'johnsmith823@fakeuser.com'},
#                  {'access': 'admin', 'id': 'travisrichardson@flywheel.io'},
#                  {'access': 'admin', 'id': 'rainergoebel@gmail.com'},
#                  {'access': 'admin', 'id': 'harshakethineni@flywheel.io'},
#                  {'access': 'rw', 'id': 'ashleyancona@flywheel.io'},
#                  {'access': 'admin', 'id': 'justinehlert@flywheel.io'},
#                  {'access': 'ro', 'id': 'andrewnemzek@invenshure.com'},
#                  {'access': 'ro', 'id': 'inijim@gmail.com'},
#                  {'access': 'ro', 'id': 'dpuccetti@gmail.com'},
#                  {'access': 'admin', 'id': 'danpuccettidev@gmail.com'},
#                  {'access': 'rw', 'id': 'zsafadi11@gmail.com'},
#                  {'access': 'admin', 'id': 'linajohnson@flywheel.io'},
#                  {'access': 'admin', 'id': 'alonnafrazier@flywheel.io'},
#                  {'access': 'admin', 'id': 'qa-tester@adtest.flywheel.io'},
#                  {'access': 'admin', 'id': 'jeffmeier@flywheel.io'},
#                  {'access': 'admin', 'id': 'roycollins@flywheel.io'},
#                  {'access': 'ro', 'id': 'jodyzeitler@flywheel.io'},
#                  {'access': 'admin', 'id': 'kalebfischer@flywheel.io'}],
#  'project': {'id': '576be50c59b2b6346719ee4d', 'label': 'Anxiety Study'},
#  'return_type': 'session',
#  'session': {'created': datetime.datetime(2016, 6, 23, 14, 23, 20, 737000, tzinfo=tzutc()),
#              'id': '576bf0d859b2b6346719f208',
#              'label': 'ccirc_sub_6_ccirc_ses2_protB',
#              'timestamp': datetime.datetime(2014, 5, 7, 8, 42, 38, tzinfo=tzutc())},
#  'subject': {'code': 'ccirc_sub_6'}}

# %%
import pandas as pd
def session_search_to_df(query):
    search = fw.search({'return_type': 'session', 'structured_query': query})
    view = fw.View(columns=['session.timestamp','subject.label','project.label'])
    df_list = []
    for item in search:
        session_id = item.session.id
        project_id = item.project.id
        tmp_df = fw.read_view_dataframe(view, project_id)
        tmp_df = tmp_df[tmp_df['session.id']==session_id]
        df_list.append(tmp_df)
    df = pd.concat(df_list)   
    return df

# %%
len([])
# Out:
# 0

# %%
search = fw.search({'return_type': 'acquisition', 'structured_query': test_query})

# %%
for item in search:
    key = 'acquisition'
    print(item[key].id)
# Out:
# 581a328c14116000143383e6
# 576d2380a02c8621973ed3de
# 576d2579a02c8621973ed55d
# 576d2589a02c8621973ed567
# 576d1f7ba02c8621973ed0d5
# 576d1f80a02c8621973ed0d9
# 576d2576a02c8621973ed559
# 576d2053a02c8621973ed188
# 576d2062a02c8621973ed195
# 576d2069a02c8621973ed19b
# 576d227aa02c8621973ed320
# 576d2377a02c8621973ed3d6
# 576d2378a02c8621973ed3d8
# 576d2379a02c8621973ed3d9
# 576d2383a02c8621973ed3df
# 576d2398a02c8621973ed3f2
# 576d23a4a02c8621973ed3fc
# 576d2419a02c8621973ed457
# 576d2427a02c8621973ed461
# 576d2453a02c8621973ed47f
# 576d2460a02c8621973ed489
# 576d2586a02c8621973ed563
# 576d1f76a02c8621973ed0cd
# 576d1f76a02c8621973ed0cf
# 576d1f77a02c8621973ed0d0
# 576d1f82a02c8621973ed0da
# 576d1f83a02c8621973ed0db
# 576d2377a02c8621973ed3d7
# 576d237da02c8621973ed3da
# 576d237ea02c8621973ed3dc
# 576d2393a02c8621973ed3ed
# 576d2573a02c8621973ed555
# 576d2573a02c8621973ed556
# 576d2573a02c8621973ed557
# 576d2575a02c8621973ed558
# 576d257ca02c8621973ed55e
# 576d257ea02c8621973ed55f
# 576d257ea02c8621973ed560
# 576d257fa02c8621973ed561
# 576d2580a02c8621973ed562
# 576d1f78a02c8621973ed0d1
# 576d1f7aa02c8621973ed0d4
# 576d204ba02c8621973ed182
# 576d204da02c8621973ed183
# 576d2057a02c8621973ed189
# 576d2059a02c8621973ed18a
# 576d205aa02c8621973ed18b
# 576d205ba02c8621973ed18e
# 576d205da02c8621973ed18f
# 576d205ea02c8621973ed190
# 576d206ca02c8621973ed19c
# 576d206ea02c8621973ed19d
# 576d2272a02c8621973ed318
# 576d2273a02c8621973ed31a
# 576d2273a02c8621973ed31b
# 576d227da02c8621973ed321
# 576d237da02c8621973ed3db
# 576d237fa02c8621973ed3dd
# 576d2391a02c8621973ed3ea
# 576d2392a02c8621973ed3ec
# 576d239ba02c8621973ed3f3
# 576d239da02c8621973ed3f4
# 576d239ea02c8621973ed3f6
# 576d239fa02c8621973ed3f7
# 576d2410a02c8621973ed44f
# 576d2410a02c8621973ed451
# 576d2411a02c8621973ed452
# 576d241ea02c8621973ed458
# 576d2421a02c8621973ed459
# 576d2421a02c8621973ed45b
# 576d2422a02c8621973ed45c
# 576d242ca02c8621973ed462
# 576d244ba02c8621973ed477
# 576d244ba02c8621973ed479
# 576d244da02c8621973ed47a
# 576d2456a02c8621973ed480
# 576d2458a02c8621973ed481
# 576d2459a02c8621973ed483
# 576d245aa02c8621973ed484
# 576d2464a02c8621973ed48a
# 576d1f76a02c8621973ed0ce
# 576d1f79a02c8621973ed0d3
# 576d1f7ea02c8621973ed0d6
# 576d1f7fa02c8621973ed0d8
# 576d204fa02c8621973ed184
# 576d205ba02c8621973ed18d
# 576d2060a02c8621973ed192
# 576d2061a02c8621973ed194
# 576d2067a02c8621973ed198
# 576d2277a02c8621973ed31c
# 576d2385a02c8621973ed3e0
# 576d2386a02c8621973ed3e2
# 576d2387a02c8621973ed3e3
# 576d238da02c8621973ed3e8
# 576d238fa02c8621973ed3e9
# 576d2394a02c8621973ed3ee
# 576d23a0a02c8621973ed3f8
# 576d2415a02c8621973ed453
# 576d2423a02c8621973ed45d
# 576d244fa02c8621973ed47b

# %%
session_search_to_df(test_query)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-7b019663d3b5> in <module>
# ----> 1 session_search_to_df(test_query)
#
# <ipython-input-198-7963ce108299> in session_search_to_df(query)
#      10         tmp_df = tmp_df[tmp_df['session.id']==session_id]
#      11         df_list.append(tmp_df)
# ---> 12     df = pd.concat(df_list)
#      13     return df
#      14
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     257
#     258         if len(objs) == 0:
# --> 259             raise ValueError('No objects to concatenate')
#     260
#     261         if keys is None:
#
# ValueError: No objects to concatenate

# %%
project_list = []
session_list = []
for item in search:
    project_list.append(item.project.id)
# Only list unique projects
project_list = list(set(project_list))

# %%
fw.View(columns = 'session.id')
# Out:
# {'columns': [{'dst': None, 'expr': None, 'src': 'session.id', 'type': None}],
#  'file_spec': None,
#  'id': None,
#  'include_ids': True,
#  'include_labels': True,
#  'label': None,
#  'missing_data_strategy': None,
#  'parent': None,
#  'public': False}

# %%
fw.View(columns = "acquisition")
# Out:
# {'columns': [{'dst': None, 'expr': None, 'src': 'acquisition', 'type': None}],
#  'file_spec': None,
#  'id': None,
#  'include_ids': True,
#  'include_labels': True,
#  'label': None,
#  'missing_data_strategy': None,
#  'parent': None,
#  'public': False}

# %%
fw.read_view_dataframe(view,project_list[1])
# Out:
#                   project.id      project.label   session.age  \
# 0   5a01d9c01c333b001c1eb31e  Anxiety Study RTS  1.299687e+09
# 1   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 2   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 3   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 4   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 5   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 6   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 7   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 8   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 9   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 10  5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
#
#                   session.id                 session.label session.operator  \
# 0   576beb3a59b2b6346719f0dd  ccirc_sub_3_ccirc_ses1_protA    Operator Name
# 1   5a01d9c11c333b00171eb323         anx_s1_anx_ses1_protA             None
# 2   5bb28a2455aeed0010680561                     new empty             None
# 3   5a01da8f1c333b001c1eb344        anx_s10_anx_ses2_protB             None
# 4   5a01dafd1c333b00191eb338         anx_s2_anx_ses1_protA             None
# 5   5a01dbe31c333b001c1eb397         anx_s2_anx_ses2_protB             None
# 6   5a01dc871c333b001c1eb3bd         anx_s3_anx_ses1_protA             None
# 7   5a01dc881c333b00191eb357         anx_s3_anx_ses2_protB             None
# 8   5a01dc891c333b001a1eb346         anx_s4_anx_ses1_protA             None
# 9   5a9862392021f3001c3278a5                  Test SEssion             None
# 10  5bf2d8e135d789001515e77c                          test             None
#
#       session.timestamp session.timezone  session.weight  \
# 0   2015-02-15 13:44:00                              NaN
# 1                  None             None             NaN
# 2   2018-10-01 20:57:00             None             NaN
# 3                  None             None             NaN
# 4                  None             None             NaN
# 5                  None             None             NaN
# 6                  None             None             NaN
# 7                  None             None             NaN
# 8                  None             None             NaN
# 9   2018-03-01 20:27:00             None             NaN
# 10  2018-11-19 15:38:00             None             NaN
#
#                   subject.id subject.label
# 0   5ab4226f25cd370001cee659   ccirc_sub_3
# 1   5ab4226f25cd370001cee6cc        anx_s1
# 2   5ab4226f25cd370001cee6cc        anx_s1
# 3   5ab4226f25cd370001cee64e       anx_s10
# 4   5ab4226f25cd370001cee6b9        anx_s2
# 5   5ab4226f25cd370001cee6b9        anx_s2
# 6   5ab4227025cd370001cee72b        anx_s3
# 7   5ab4227025cd370001cee72b        anx_s3
# 8   5ab4226f25cd370001cee5e6        anx_s4
# 9   5ab4226f25cd370001cee674        243253
# 10  5c670e8265ce24002d0cbc14   depr_pat_s4

# %%
fw.read_view_dataframe(view,'576bf0d859b2b6346719f208')
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-173-16a127a0b757> in <module>
# ----> 1 fw.read_view_dataframe(view,'576bf0d859b2b6346719f208')
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/client.py in read_view_dataframe(self, view, container_id, opts, **kwargs)
#     225         :return: A pandas DataFrame
#     226         """
# --> 227         return self._fw.read_view_dataframe(view, container_id, opts=opts, **kwargs)
#     228
#     229
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/flywheel.py in read_view_dataframe(self, view, container_id, opts, **kwargs)
#    6875
#    6876         kwargs['format'] = 'json-flat'
# -> 6877         resp = self.read_view_data(view, container_id, decode=False, **kwargs)
#    6878         if resp:
#    6879             try:
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/flywheel.py in read_view_data(self, view, container_id, decode, **kwargs)
#    6851             resp = self.views_api.evaluate_view_with_http_info(view, container_id, **kwargs)
#    6852         else:
# -> 6853             resp = self.views_api.evaluate_view_adhoc_with_http_info(container_id, view, **kwargs)
#    6854         resp.raw.decode_content = True
#    6855         if decode:
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api/views_api.py in evaluate_view_adhoc_with_http_info(self, container_id, body, **kwargs)
#     453             _request_timeout=params.get('_request_timeout'),
#     454             _request_out=params.get('_request_out'),
# --> 455             collection_formats=collection_formats)
#     456
#     457     def get_view(self, view_id, **kwargs):  # noqa: E501
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _request_out)
#     348                                    response_type, auth_settings,
#     349                                    _return_http_data_only, collection_formats,
# --> 350                                    _preload_content, _request_timeout, _request_out)
#     351         else:
#     352             thread = self.pool.apply_async(self.__call_api, (resource_path,
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _request_out)
#     178             post_params=post_params, body=body,
#     179             _preload_content=_preload_content,
# --> 180             _request_timeout=_request_timeout)
#     181
#     182         self.last_response = response_data
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     391                                          _preload_content=_preload_content,
#     392                                          _request_timeout=_request_timeout,
# --> 393                                          body=body)
#     394         elif method == "PUT":
#     395             return self.rest_client.PUT(url,
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/rest.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     223                             _preload_content=_preload_content,
#     224                             _request_timeout=_request_timeout,
# --> 225                             body=body)
#     226
#     227     def PUT(self, url, headers=None, query_params=None, post_params=None,
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     126                     stream=stream,
#     127                     timeout=_request_timeout,
# --> 128                     headers=headers)
#     129             elif headers['Content-Type'] == 'application/x-www-form-urlencoded':  # noqa: E501
#     130                 r = self.session.request(method, url,
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     651
#     652         # Response manipulation hooks
# --> 653         r = dispatch_hook('response', hooks, r, **kwargs)
#     654
#     655         # Persist cookies
#
# ~/anaconda3/lib/python3.7/site-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29             hooks = [hooks]
#      30         for hook in hooks:
# ---> 31             _hook_data = hook(hook_data, **kwargs)
#      32             if _hook_data is not None:
#      33                 hook_data = _hook_data
#
# ~/anaconda3/lib/python3.7/site-packages/flywheel/rest.py in response_hook(self, resp, *args, **kwargs)
#      76     def response_hook(self, resp, *args, **kwargs):
#      77         if not 200 <= resp.status_code <= 299 and resp.status_code != 302:
# ---> 78             raise ApiException(http_resp=resp)
#      79
#      80     def request(self, method, url, query_params=None, headers=None,
#
# ApiException: (500) Reason: Internal Server Error

# %%
df_list = []
for project in project_list:
    try:
        tmp_df = fw.read_view_dataframe(view,project)
        #print(len(project.sessions()))
        df_list.append(tmp_df)
    except:
        print(project)
df = pd.concat(df_list)
# Out:
# 576be74e59b2b6346719ef83
# 576be9a259b2b6346719f074
# 576bf2a759b2b6346719f246

# %%
df
# Out:
#                   project.id      project.label   session.age  \
# 0   5a01d9c01c333b001c1eb31e  Anxiety Study RTS  1.299687e+09
# 1   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 2   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 3   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 4   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 5   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 6   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 7   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 8   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 9   5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 10  5a01d9c01c333b001c1eb31e  Anxiety Study RTS           NaN
# 0   5b3101cb585391001917b30c         Dan Test 2  7.253280e+08
# 1   5b3101cb585391001917b30c         Dan Test 2  1.072224e+09
# 2   5b3101cb585391001917b30c         Dan Test 2           NaN
# 3   5b3101cb585391001917b30c         Dan Test 2           NaN
# 4   5b3101cb585391001917b30c         Dan Test 2           NaN
# 0   576bfb0159b2b6346719f3ff     Autism Studies  1.007186e+09
# 1   576bfb0159b2b6346719f3ff     Autism Studies  1.007100e+09
# 2   576bfb0159b2b6346719f3ff     Autism Studies  4.576126e+08
# 3   576bfb0159b2b6346719f3ff     Autism Studies  1.156712e+09
# 4   576bfb0159b2b6346719f3ff     Autism Studies  1.156712e+09
# 5   576bfb0159b2b6346719f3ff     Autism Studies  1.072084e+09
# 6   576bfb0159b2b6346719f3ff     Autism Studies  1.072084e+09
# 7   576bfb0159b2b6346719f3ff     Autism Studies  1.240329e+09
# 8   576bfb0159b2b6346719f3ff     Autism Studies  1.240329e+09
# 9   576bfb0159b2b6346719f3ff     Autism Studies           NaN
# 10  576bfb0159b2b6346719f3ff     Autism Studies           NaN
# 11  576bfb0159b2b6346719f3ff     Autism Studies           NaN
# 12  576bfb0159b2b6346719f3ff     Autism Studies           NaN
# 13  576bfb0159b2b6346719f3ff     Autism Studies           NaN
# 0   576be50c59b2b6346719ee4d      Anxiety Study  1.252980e+09
# 1   576be50c59b2b6346719ee4d      Anxiety Study  1.227764e+09
# 2   576be50c59b2b6346719ee4d      Anxiety Study  1.023075e+09
# 3   576be50c59b2b6346719ee4d      Anxiety Study           NaN
# 4   576be50c59b2b6346719ee4d      Anxiety Study           NaN
# 5   576be50c59b2b6346719ee4d      Anxiety Study           NaN
# 6   576be50c59b2b6346719ee4d      Anxiety Study           NaN
# 7   576be50c59b2b6346719ee4d      Anxiety Study  6.937920e+08
# 8   576be50c59b2b6346719ee4d      Anxiety Study           NaN
# 9   576be50c59b2b6346719ee4d      Anxiety Study           NaN
# 10  576be50c59b2b6346719ee4d      Anxiety Study  1.670112e+09
# 11  576be50c59b2b6346719ee4d      Anxiety Study  1.009152e+09
# 12  576be50c59b2b6346719ee4d      Anxiety Study  1.009152e+09
# 13  576be50c59b2b6346719ee4d      Anxiety Study  9.776160e+08
#
#                   session.id                 session.label session.operator  \
# 0   576beb3a59b2b6346719f0dd  ccirc_sub_3_ccirc_ses1_protA    Operator Name
# 1   5a01d9c11c333b00171eb323         anx_s1_anx_ses1_protA             None
# 2   5bb28a2455aeed0010680561                     new empty             None
# 3   5a01da8f1c333b001c1eb344        anx_s10_anx_ses2_protB             None
# 4   5a01dafd1c333b00191eb338         anx_s2_anx_ses1_protA             None
# 5   5a01dbe31c333b001c1eb397         anx_s2_anx_ses2_protB             None
# 6   5a01dc871c333b001c1eb3bd         anx_s3_anx_ses1_protA             None
# 7   5a01dc881c333b00191eb357         anx_s3_anx_ses2_protB             None
# 8   5a01dc891c333b001a1eb346         anx_s4_anx_ses1_protA             None
# 9   5a9862392021f3001c3278a5                  Test SEssion             None
# 10  5bf2d8e135d789001515e77c                          test             None
# 0   5b646f75bcebb107ea96a7ad      05/07/14 08:42 AM - TEST    Operator Name
# 1   5bfda737a26233f306a24445             07/14/12 12:14 PM    Operator Name
# 2   5b646fbfbcebb107ea96a7af             05/24/18 14:50 PM             None
# 3   5bb6231bf9090600126ceaac                         asdfb             None
# 4   5bb6233af9090600146cea8a                         Test2             None
# 0   576bfb0359b2b6346719f400  asd_pat_s4_s1_pA_t1_fmri_dti    Operator Name
# 1   576bfb1459b2b6346719f40b  asd_pat_s4_s2_pA_t1_fmri_dti    Operator Name
# 2   576bfc1559b2b6346719f442  asd_pat_s2_s1_pA_t1_fmri_dti    Operator Name
# 3   576bfd5b59b2b6346719f49a  asd_pat_s3_s1_pA_t1_fmri_dti    Operator Name
# 4   576bfd7e59b2b6346719f4a5  asd_pat_s3_s2_pA_t1_fmri_dti    Operator Name
# 5   576bfd8d59b2b6346719f4b0           asdyadyasiudyiuyasd    Operator Name
# 6   576bfd9b59b2b6346719f4bb  asd_pat_s1_s2_pA_t1_fmri_dti    Operator Name
# 7   576c019859b2b6346719f5a2  asd_pat_s5_s1_pA_t1_fmri_dti    Operator Name
# 8   576c01ec59b2b6346719f5ad  asd_pat_s5_s2_pA_t1_fmri_dti    Operator Name
# 9   5806611dd213ed776045b333             09/10/15 11:58 AM             None
# 10  596e320c8b5262001d7f3393              Test123123123123             None
# 11  5a9f12c1705b16001cb674f8                     to delete             None
# 12  5bd0cb7c6dbfe70011b62d84                kl;adfsjkladfs             None
# 13  5c33b48a85af7100290d9d88                       Testrs1             None
# 0   576be5d059b2b6346719ef31         anx_s5_anx_ses1_protA    Operator Name
# 1   576bf0d859b2b6346719f208  ccirc_sub_6_ccirc_ses2_protB    Operator Name
# 2   576bf61959b2b6346719f2f7   depr_pat_s4_depr_ses1_pcolA    Operator Name
# 3   59de3fe8e01776001be670c5                         sess1             None
# 4   5bf2d93f35d7890014a4b310                          test             None
# 5   5bff2813132a030013fed2d7                          test             None
# 6   581a2f8114116000153383e2           Testing New Session             None
# 7   5a9ed3720b0804001b1c3201                 To be deleted            dania
# 8   5aa17251705b160017b677c9                   Test delete             None
# 9   5aa172cf705b16001ab677f7                        grshjd             None
# 10  5ae36cad9e6970ecbb2ba86d             02/15/15 13:44 PM    Operator Name
# 11  5c537866f0fbbc0f22a34b6c             06/04/13 22:36 PM    Operator Name
# 12  5cbf46ad28801c002dc6a942         anx_s1_anx_ses2_protB    Operator Name
# 13  5cbf46ae28801c0029c6a87b         anx_s1_anx_ses1_protA    Operator Name
#
#              session.timestamp session.timezone  session.weight  \
# 0          2015-02-15 13:44:00                              NaN
# 1                         None             None             NaN
# 2          2018-10-01 20:57:00             None             NaN
# 3                         None             None             NaN
# 4                         None             None             NaN
# 5                         None             None             NaN
# 6                         None             None             NaN
# 7                         None             None             NaN
# 8                         None             None             NaN
# 9          2018-03-01 20:27:00             None             NaN
# 10         2018-11-19 15:38:00             None             NaN
# 0          2014-05-07 08:42:38              NaN             NaN
# 1          2012-07-14 12:14:25              NaN             NaN
# 2                         None              NaN             NaN
# 3          2018-10-04 14:26:00              NaN             NaN
# 4          2018-10-04 14:27:00              NaN             NaN
# 0          2015-01-07 17:30:00                              NaN
# 1          2015-01-07 17:30:03                              NaN
# 2          2015-01-07 17:30:03                              NaN
# 3          2015-01-07 17:30:03                              NaN
# 4          2015-01-07 17:30:03                              NaN
# 5          2015-02-15 13:44:00                              NaN
# 6          2015-01-07 17:30:03                              NaN
# 7          2015-01-07 17:30:03                              NaN
# 8          2015-01-07 17:30:03                              NaN
# 9          2015-09-10 11:58:40             None             NaN
# 10         2017-07-18 16:06:00             None             NaN
# 11         2018-03-06 22:14:00             None             NaN
# 12         2018-10-24 19:43:00             None             NaN
# 13         2019-01-07 20:20:00             None             NaN
# 0          2015-01-07 17:30:03                              NaN
# 1          2014-05-07 08:42:38                              NaN
# 2          2015-01-07 17:30:03                              NaN
# 3   2017-10-11 15:56:43.477000  America/Chicago             NaN
# 4          2018-11-19 15:38:00             None             NaN
# 5          2018-11-19 15:38:00             None             NaN
# 6          2016-11-02 05:00:00             None             NaN
# 7          2018-03-06 17:44:00             None             NaN
# 8          2018-03-08 17:26:00             None             NaN
# 9          2018-03-08 17:28:00             None             NaN
# 10         2015-02-15 13:44:37             None             NaN
# 11         2013-06-04 22:36:20             None             NaN
# 12         2013-06-04 22:36:20             None             NaN
# 13         2014-11-13 16:25:16             None             NaN
#
#                   subject.id subject.label
# 0   5ab4226f25cd370001cee659   ccirc_sub_3
# 1   5ab4226f25cd370001cee6cc        anx_s1
# 2   5ab4226f25cd370001cee6cc        anx_s1
# 3   5ab4226f25cd370001cee64e       anx_s10
# 4   5ab4226f25cd370001cee6b9        anx_s2
# 5   5ab4226f25cd370001cee6b9        anx_s2
# 6   5ab4227025cd370001cee72b        anx_s3
# 7   5ab4227025cd370001cee72b        anx_s3
# 8   5ab4226f25cd370001cee5e6        anx_s4
# 9   5ab4226f25cd370001cee674        243253
# 10  5c670e8265ce24002d0cbc14   depr_pat_s4
# 0   5b646f755cdfcc000fe785a0    Patient ID
# 1   5b646f755cdfcc000fe785a0    Patient ID
# 2   5b646fbf5cdfcc0012e7860f    Dan's Test
# 3   5b646fbf5cdfcc0012e7860f    Dan's Test
# 4   5b646fbf5cdfcc0012e7860f    Dan's Test
# 0   5ab4227025cd370001cee726    asd_pat_s4
# 1   5ab4227025cd370001cee726    asd_pat_s4
# 2   5ab4227025cd370001cee761    asd_pat_s2
# 3   5ab4227025cd370001cee76b    asd_pat_s3
# 4   5ab4227025cd370001cee76b    asd_pat_s3
# 5   5ab4226f25cd370001cee64b    asd_pat_s1
# 6   5ab4226f25cd370001cee64b    asd_pat_s1
# 7   5ab4226f25cd370001cee696    asd_pat_s5
# 8   5ab4226f25cd370001cee696    asd_pat_s5
# 9   5ab4226f25cd370001cee670          B101
# 10  5ab4226f25cd370001cee649     ExampleID
# 11  5ab4226f25cd370001cee5c8        fdsfhf
# 12  5bd0cb7c6dbfe70011b62d83  dfaskl;fdkla
# 13  5c33b48a85af7100290d9d87       Testrs1
# 0   5ab4226f25cd370001cee6ae        anx_s5
# 1   5ab4226f25cd370001cee619   ccirc_sub_6
# 2   5ab4227025cd370001cee729   depr_pat_s4
# 3   5ab4227025cd370001cee729   depr_pat_s4
# 4   5ab4227025cd370001cee729   depr_pat_s4
# 5   5ab4227025cd370001cee729   depr_pat_s4
# 6   5ab4226f25cd370001cee605          1234
# 7   5ab4227025cd370001cee743        423546
# 8   5ab4226f25cd370001cee703    delete acq
# 9   5ab4226f25cd370001cee5c4        grfhtg
# 10  5bb3e7d3ea73c100157b776f          dsfg
# 11  5c537865f5929e002dcab3eb    Patient ID
# 12  5cbf46ad28801c002dc6a941        anx_s1
# 13  5cbf46ad28801c002dc6a941        anx_s1

# %%
len(fw.projects()[0].sessions())
# Out:
# 8

# %%
project_list
# Out:
# ['576be9a259b2b6346719f074',
#  '576be74e59b2b6346719ef83',
#  '576be50c59b2b6346719ee4d',
#  '576bf2a759b2b6346719f246']

# %%
fw.acquisitions.find_first('label=TSE_100_Cor_P4 SENSE').id
# Out:
# '5cd19cfe10be197cc2bcf92e'
